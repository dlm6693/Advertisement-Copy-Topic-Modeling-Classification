# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('../Data/cleaned_ads_data.csv')

# %%
data.head()
# Out:
#                   brand        country                 medium  \
# 0     Enable Foundation            NaN  Ambient & Interactive
# 1                Tzabar         Israel                  Print
# 2              Infiniti  United States                  Print
# 3                Toyota         Canada                  Print
# 4  Friends of the Earth        Germany                  Print
#
#                                             headline  \
# 0                                                NaN
# 1  roger waters live in paris 3 nights  concert €...
# 2                            accelerating the future
# 3    official ride of the spinfest amateur dj awards
# 4  travelling fruits cause pollution think global...
#
#                                          description  \
# 0  surreal is real in dementia is an awareness ca...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                        industry
# 0  Public interest & Non-profit
# 1           Transport & Tourism
# 2         Automotive & Services
# 3         Automotive & Services
# 4  Public interest & Non-profit

# %%
desc = data.dropna(subset=['description'])
len(desc)
# Out:
# 17608

# %%
desc.head()
# Out:
#                brand         country                 medium  \
# 0  Enable Foundation             NaN  Ambient & Interactive
# 6          Fedrigoni             NaN      Design & Branding
# 7            Spontex          France                  Cyber
# 8          Coca-Cola         Denmark      Promotion & Event
# 9                DOE  United Kingdom                  Print
#
#                          headline  \
# 0                             NaN
# 6                             NaN
# 7                             NaN
# 8  makes monday taste like friday
# 9           no seatbelt no excuse
#
#                                          description  \
# 0  surreal is real in dementia is an awareness ca...
# 6  pulp is a quarterly journal of people and pape...
# 7  execution  each time a page would post the pic...
# 8  summary in 2006 the northern european market f...
# 9  how a nineyear investment of â£868m in road sa...
#
#                        industry
# 0  Public interest & Non-profit
# 6          Non-alcoholic drinks
# 7          House, Garden & Pets
# 8          Non-alcoholic drinks
# 9  Public interest & Non-profit

# %%
desc[desc.duplicated(subset=['description'])]
# Out:
#                                           brand               country  \
# 1504                                 StreetEasy         United States
# 1777                         U.S. Census Bureau         United States
# 1847                           New York Lottery         United States
# 1921                                     Virgin             Australia
# 2043                                        NaN                   NaN
# 2074            HSL - Helsinki Region Transport               Finland
# 2116                      Australian Government                   NaN
# 2407                                        NaN                 Chile
# 2451                                 Widow Jane         United States
# 2738                             City of Geneva           Switzerland
# 2927                         U.S. Census Bureau         United States
# 3390                                        BBC        United Kingdom
# 4020                           New York Lottery         United States
# 4203                                     Diesel        United Kingdom
# 4381                                  Coca-Cola               Denmark
# 5000                      League Against Cancer              Slovakia
# 5079                                    Psiphon                Canada
# 5738           International Mini Kancil Awards              Malaysia
# 5766                      exhale Barre·Yoga·Spa         United States
# 5827                      League Against Cancer              Slovakia
# 5875                                Mount Sinai         United States
# 6028                   Cairo Festival City Mall                   NaN
# 6077                                        NaN                 Spain
# 6226                                     Toyota        Czech Republic
# 6228                                      Evian         United States
# 6308                                        NaN             Singapore
# 6599                        Weylandts Furniture          South Africa
# 6631                                        NaN             Singapore
# 6700                                     Diesel        United Kingdom
# 6740                                 Volkswagen             Argentina
# ...                                         ...                   ...
# 37299                             Breathe Right         United States
# 37348                          Odell Brewing Co         United States
# 37357                                     AVIVA                France
# 37393                      Department of Health        United Kingdom
# 37403                                   Philips  United Arab Emirates
# 37438                                 Billy Tea             Australia
# 37444                                      FLAG              Portugal
# 37467                                   Bacardi        United Kingdom
# 37518              Reform Political Advertising                   NaN
# 37590                            Colégio Darwin                Brazil
# 37602                                      Bawx         United States
# 37635                   Kennedy Health Alliance         United States
# 37649                                       NaN                   NaN
# 37696                                Greenpeace        Czech Republic
# 37720                          The Sunday Times        United Kingdom
# 37799                                   TrueCar         United States
# 37831                   Anthony’s Pizza & Pasta         United States
# 37837                                       JWT         United States
# 37843                           Corpus Academia                Brazil
# 37882        Texas Department of Transportation         United States
# 37888                               Otorrino Já                Brazil
# 37892                                     Exame                Brazil
# 37999                              Drive-in Box                Brazil
# 38029  Romanian Alliance for Suicide Prevention               Romania
# 38045                                 Nutravita                 Egypt
# 38067                                Meat Fight         United States
# 38068             National Network for Children              Bulgaria
# 38071                        The Unzipped Truth         United States
# 38096                                       JWT         United States
# 38106                                     Smart        Czech Republic
#
#                       medium  \
# 1504                 Outdoor
# 1777                   Print
# 1847                   Print
# 1921                   Radio
# 2043                   Print
# 2074                   Print
# 2116                   Print
# 2407                   Print
# 2451                 Outdoor
# 2738                   Print
# 2927                   Print
# 3390             TV & Cinema
# 4020                   Print
# 4203                   Print
# 4381                   Print
# 5000                   Print
# 5079                 Outdoor
# 5738                   Print
# 5766                   Print
# 5827                   Print
# 5875                   Print
# 6028                   Print
# 6077                   Print
# 6226             TV & Cinema
# 6228                   Print
# 6308                   Print
# 6599                   Print
# 6631                   Print
# 6700                   Print
# 6740                   Print
# ...                      ...
# 37299                  Print
# 37348                  Print
# 37357                  Print
# 37393                  Print
# 37403  Ambient & Interactive
# 37438                  Print
# 37444                  Print
# 37467                  Print
# 37518                  Print
# 37590                  Print
# 37602                  Cyber
# 37635                  Print
# 37649                  Print
# 37696                  Print
# 37720                  Print
# 37799            TV & Cinema
# 37831                  Radio
# 37837                Outdoor
# 37843                  Print
# 37882                  Print
# 37888                  Print
# 37892                  Print
# 37999                  Print
# 38029                  Print
# 38045                  Print
# 38067                  Print
# 38068                Outdoor
# 38071                Outdoor
# 38096                Outdoor
# 38106                  Print
#
#                                                 headline  \
# 1504   ive been hiding a saint berdoodle from my land...
# 1777                  its for our ohana its in our hands
# 1847   you shop the market rises yeah that kind of ri...
# 1921                                                 NaN
# 2043                        find concerts in a new place
# 2074   throught the lens of will burrardlucas walking...
# 2116   he stepped over it when he went into my email ...
# 2407   guarranteed satisfaction if youre not satisfie...
# 2451   crafted with pure mineral water from the same ...
# 2738   throwing butts in a manhole easy  getting it o...
# 2927          the strength of our people is in our voice
# 3390            if you love where you live be part of it
# 4020   your butler has a butler yeah that kind of ric...
# 4203   smart listens to the head stupid listens to th...
# 4381                               real taste zero sugar
# 5000                       smoking it will be your fault
# 5079   an error occurred please try again in another ...
# 5738   ddb international callforentries deadline marc...
# 5766   the stress of the mind melts in the touch of t...
# 5827                       obesity it will be your fault
# 5875   when researching hospitals consider how much r...
# 6028   lets talk about love for shopping entertainmen...
# 6077                                  use original parts
# 6226                      the ingenious new toyota yaris
# 6228                                                 NaN
# 6308   give a man a fish and hell live for a day give...
# 6599     explore our range of hand crafted leather sofas
# 6631              the road to progress stars with a road
# 6700              stupid is trial and error mostly error
# 6740   soy soya production 1998  2018 copy text 20 ye...
# ...                                                  ...
# 37299                              quit protesting sleep
# 37348                                  dive bar approved
# 37357                                                NaN
# 37393  protect children dont make them breathe cigare...
# 37403  headline go pro  red bull  the adventure pair ...
# 37438  tea from a time when a deep conversation meant...
# 37444  coconuts kill more people than sharks you’ve j...
# 37467             we remember prohibition it was a blast
# 37518  the uk plays £millions a day funding the chari...
# 37590  the earth will be invaded by aliens if you rea...
# 37602  model 10 car fort house model 20 submarine cav...
# 37635  i’m not a doctor but i know what i want from o...
# 37649  pepper wont make you sneeze itll make you gree...
# 37696               is greenpeace a leftist organization
# 37720  drive awareness of the rich list and drive sal...
# 37799  when buying a car we all want a great deal yet...
# 37831  a silent scourge has spread among the youth of...
# 37837  innovation be an idea stuntman don your glitte...
# 37843  studying until the small hours come to the gym...
# 37882  dont be strapped for cash nash buckle up every...
# 37888  losing your breath is good but just at the rig...
# 37892  from childs play to grown ups business 862 bus...
# 37999  you can come out of the closet without leaving...
# 38029  find the reason before its too late sexual abu...
# 38045  your ambitions are the impossible  d makes all...
# 38067               losers have their ash handed to them
# 38068  for candy theft some children are put behind b...
# 38071                     why is modern art so expensive
# 38096  conviction breed lightning bolts make magic st...
# 38106            simplified commuting and transportation
#
#                                              description  \
# 1504   find your place showcases all of the amenities...
# 1777   the objective is to encourage native hawaiians...
# 1847   ddb new york has created a new typeface made o...
# 1921   description  synopsis   this is a story about ...
# 2043                                        via adverbox
# 2074   wildlife photographer will burrardlucas photog...
# 2116   the australian government is running the line ...
# 2407   its a series of 10 print ads that speak about ...
# 2451   to build a great city you start with the tough...
# 2738   the city of geneva is launching a campaign to ...
# 2927   the objective is to encourage native hawaiians...
# 3390   bbc local radio is the spark that ignites loca...
# 4020   ddb new york has created a new typeface made o...
# 4203         campaign microsite httpwwwdieselcombestupid
# 4381   summary in 2006 the northern european market f...
# 5000   note a wordplay is employed in the slogan base...
# 5079   psiphon is a circumvention tool from that util...
# 5738                                        via adverbox
# 5766   our thoughts are the keys to opening the myste...
# 5827   note a wordplay is employed in the slogan base...
# 5875   to inform the masses about the mount sinai hea...
# 6028   inspired by the worldrenowned artist rené magr...
# 6077                                     source goodness
# 6226   in 2003  twice as old as its segmentâs avera...
# 6228   new print campaign for evian by betc out on ma...
# 6308   the national youth councils youth expedition p...
# 6599   how do we take a brand that focus traditionall...
# 6631   the national youth councils youth expedition p...
# 6700         campaign microsite httpwwwdieselcombestupid
# 6740   trucks are fundamental for national commerce t...
# ...                                                  ...
# 37299  a habitual snorer keeps his or her partner up ...
# 37348  as the only americanstyle india pale ale ipa t...
# 37357  original tagline téléphoner ou utiliser un kit...
# 37393  since the tobacco control campaign was launche...
# 37403  challenge philips is an iconic brand borne out...
# 37438  choice of your dad’s dad’s dad campaign a prin...
# 37444  more important than learning is learning somet...
# 37467  everyone has a story the bacardí brand and fam...
# 37518  analogfolk is proud to support the coalition f...
# 37590  colégio darwin is a school located in brazil w...
# 37602  in a charity fundraising effort independent ad...
# 37635  research that showed that patients want contro...
# 37649                credit creative panel cochin adclub
# 37696  as the key visual of the campaign we used a pi...
# 37720  brief drive awareness of the rich list and dri...
# 37799  the campaign is a brand relaunch emphasizing t...
# 37831  with the goal of separating anthony’s from inf...
# 37837  series of posters created for jwt atlantas new...
# 37843  explanation campaign created to show how peopl...
# 37882  texas teens are less likely to buckle up and m...
# 37888  when you need an otolaryngologist this app wil...
# 37892  brazil is a very big country known for its cha...
# 37999  drivein box is a servcar service located in cu...
# 38029  campaign addressing a multitude of reasons for...
# 38045  vitamin d is only one element but if its missi...
# 38067  promotional posters for meat fight a bbq chari...
# 38068  currently over 10 000 juveniles in bulgaria ar...
# 38071  in an attempt to start a citywide dialogue wit...
# 38096  series of posters created for jwt atlantas new...
# 38106  smart prague is the vision of the city of prag...
#
#                               industry
# 1504   Professional  & Public services
# 1777      Public interest & Non-profit
# 1847                      Toys & Games
# 1921   Professional  & Public services
# 2043                Media & Publishing
# 2074      Public interest & Non-profit
# 2116      Public interest & Non-profit
# 2407                         Education
# 2451                  Alcoholic drinks
# 2738      Public interest & Non-profit
# 2927      Public interest & Non-profit
# 3390                Media & Publishing
# 4020                      Toys & Games
# 4203      Apparel, Clothing & Footwear
# 4381              Non-alcoholic drinks
# 5000      Public interest & Non-profit
# 5079        Electronics & Audio-Visual
# 5738   Professional  & Public services
# 5766                   Beauty & Health
# 5827      Public interest & Non-profit
# 5875                   Beauty & Health
# 6028             Retail & Distribution
# 6077             Automotive & Services
# 6226             Automotive & Services
# 6228              Non-alcoholic drinks
# 6308      Public interest & Non-profit
# 6599              House, Garden & Pets
# 6631      Public interest & Non-profit
# 6700      Apparel, Clothing & Footwear
# 6740             Automotive & Services
# ...                                ...
# 37299                  Beauty & Health
# 37348                 Alcoholic drinks
# 37357       Financial & Legal services
# 37393     Public interest & Non-profit
# 37403       Electronics & Audio-Visual
# 37438             Non-alcoholic drinks
# 37444                        Education
# 37467                 Alcoholic drinks
# 37518     Public interest & Non-profit
# 37590                        Education
# 37602  Professional  & Public services
# 37635                  Beauty & Health
# 37649                    Miscellaneous
# 37696     Public interest & Non-profit
# 37720               Media & Publishing
# 37799            Automotive & Services
# 37831                Catering industry
# 37837             Corporate self-promo
# 37843      Culture, Recreation & Sport
# 37882     Public interest & Non-profit
# 37888                  Beauty & Health
# 37892               Media & Publishing
# 37999  Professional  & Public services
# 38029     Public interest & Non-profit
# 38045                   Pharmaceutical
# 38067     Public interest & Non-profit
# 38068     Public interest & Non-profit
# 38071               Media & Publishing
# 38096             Corporate self-promo
# 38106        Industrial & Agricultural
#
# [798 rows x 6 columns]

# %%
desc.isnull().sum()
# Out:
# brand            880
# country         2338
# medium            72
# headline       12941
# description        0
# industry           0
# dtype: int64

# %%
desc.brand.value_counts()[:25]
# Out:
# Volkswagen                   242
# Nike                         176
# McDonald's                   151
# Samsung                      121
# IKEA                         120
# Google                       113
# Coca-Cola                    100
# Honda                         88
# adidas                        86
# Amnesty International         84
# Toyota                        84
# Audi                          78
# Heineken                      72
# Mercedes-Benz                 72
# Burger King                   72
# Apple                         67
# World Wildlife Fund (WWF)     60
# Volvo                         57
# Axe/Lynx                      55
# Nissan                        52
# BMW                           51
# Renault                       51
# Ford                          47
# UNICEF                        46
# Mars                          44
# Name: brand, dtype: int64

# %%
desc.country.value_counts()[:25]
# Out:
# United States           3213
# United Kingdom          1531
# Brazil                   925
# France                   911
# Germany                  838
# Canada                   654
# Australia                554
# Sweden                   413
# India                    395
# Spain                    340
# South Africa             336
# Netherlands              333
# Japan                    283
# Argentina                281
# China                    273
# Italy                    258
# United Arab Emirates     231
# New Zealand              222
# Belgium                  216
# Russia                   177
# Colombia                 160
# Singapore                144
# Israel                   129
# Switzerland              123
# Portugal                 118
# Name: country, dtype: int64

# %%
desc.medium.value_counts()[:25]
# Out:
# Print                    4445
# TV & Cinema              4115
# Cyber                    2542
# Design & Branding        1643
# Outdoor                  1429
# Promotion & Event        1205
# Ambient & Interactive    1000
# Direct Market             736
# Radio                     345
# Miscellaneous              76
# Name: medium, dtype: int64

# %%
desc.industry.nunique()
# Out:
# 28

# %%
X = desc.description
cv = CountVectorizer(stop_words='english', ngram_range=(1,3), analyzer=
                    'word', max_df=0.75)
desc_cv = cv.fit_transform(X)

# %%
desc_cv.shape
# Out:
# (17608, 2487856)

# %%
lda = LatentDirichletAllocation()
params = {'n_components': range(5,26), 'learning_method':['batch', 'online'],
         'learning_decay':[.5,.6,.7,.8,.9,1]}
lda_rs = RandomizedSearchCV(lda, param_distributions=params, verbose=10, n_jobs=-1)
lda_rs.fit(desc_cv)
# Out:
# C:\Users\dlm66\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed: 843.4min
# [Parallel(n_jobs=-1)]: Done  19 out of  30 | elapsed: 866.9min remaining: 501.9min
# [Parallel(n_jobs=-1)]: Done  23 out of  30 | elapsed: 871.6min remaining: 265.3min
# [Parallel(n_jobs=-1)]: Done  27 out of  30 | elapsed: 885.8min remaining: 98.4min
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed: 895.0min finished
# RandomizedSearchCV(cv='warn', error_score='raise-deprecating',
#           estimator=LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='batch', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
#              n_components=10, n_jobs=None, n_topics=None, perp_tol=0.1,
#              random_state=None, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0),
#           fit_params=None, iid='warn', n_iter=10, n_jobs=-1,
#           param_distributions={'n_components': range(5, 26), 'learning_method': ['batch', 'online'], 'learning_decay': [0.5, 0.6, 0.7, 0.8, 0.9, 1]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn', scoring=None, verbose=10)

# %%
lda_rs.best_params_
# Out:
# {'n_components': 6, 'learning_method': 'online', 'learning_decay': 0.9}

# %%
lda_model = lda_rs.best_estimator_

# %%
lda_output = lda_model.fit_transform(desc_cv)

# %%
def show_topics(vectorizer, lda_model, n_words=10):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords

# %%
show_topics(cv, lda_model)
# Out:
# [array(['vr', 'heineken', 'plastic', 'google', 'ibm', 'als', 'fish',
#         'bible', 'maps', 'god'], dtype='<U270'),
#  array(['la', 'en', 'original', 'que', 'bag', 'le', 'el', 'et', 'nissan',
#         'metal'], dtype='<U270'),
#  array(['site', 'lego', 'bmw', 'location', 'pizza', 'dimensions',
#         'veterans', 'ford', 'speed', 'war'], dtype='<U270'),
#  array(['campaign', 'people', 'new', 'media', 'brand', 'world', 'social',
#         'created', 'time', 'way'], dtype='<U270'),
#  array(['new', 'film', 'spot', 'creative', 'director', 'game', 'team',
#         'campaign', 'music', 'work'], dtype='<U270'),
#  array(['paper', 'barbie', 'fuel', 'design', 'volkswagen', 'union',
#         'dementia', 'amnesty', 'japanese', 'visual'], dtype='<U270')]
